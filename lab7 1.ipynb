# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

# %matplotlib inline

# %%
import pandas as pd

df = pd.read_csv(
    r"C:\Users\olham\Desktop\New folder\student-por.csv",
    sep=";"
)

df.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        4   0  11  11
# 1      5        3      3     1     1      3        2   9  11  11
# 2      4        3      2     2     3      3        6  12  13  12
# 3      3        2      2     1     1      5        0  14  14  14
# 4      4        3      2     1     2      5        0  11  13  13
#
# [5 rows x 33 columns]

# %%
print("Shape:", df.shape)
print("\nColumns:")
print(df.columns.tolist())

print("\nMissing values:")
print(df.isnull().sum().sort_values(ascending=False).head(10))
# Out:
# Shape: (649, 33)
#
# Columns:
# ['school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu', 'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime', 'studytime', 'failures', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery', 'higher', 'internet', 'romantic', 'famrel', 'freetime', 'goout', 'Dalc', 'Walc', 'health', 'absences', 'G1', 'G2', 'G3']
#
# Missing values:
# school     0
# sex        0
# age        0
# address    0
# famsize    0
# Pstatus    0
# Medu       0
# Fedu       0
# Mjob       0
# Fjob       0
# dtype: int64

# %%
df['pass'] = (df['G3'] >= 10).astype(int)
df[['G3', 'pass']].head()
# Out:
#    G3  pass
# 0  11     1
# 1  11     1
# 2  12     1
# 3  14     1
# 4  13     1

# %%
sns.countplot(x='pass', hue='pass', data=df, legend=False)
plt.title('Pass / Fail Distribution')
plt.show()

print(df['pass'].value_counts())
print()
print(df['pass'].value_counts(normalize=True))
# Out:
# pass
# 1    549
# 0    100
# Name: count, dtype: int64
#
# pass
# 1    0.845917
# 0    0.154083
# Name: proportion, dtype: float64

# %%
plt.figure(figsize=(10, 6))
sns.heatmap(df.select_dtypes(include=np.number).corr(), cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()

# %%
df['G3'].plot(kind='hist', bins=20)
plt.title('Distribution of Final Grade (G3)')
plt.xlabel('G3')
plt.show()

# %%
X = df.drop(columns=['G3', 'pass'])
X = pd.get_dummies(X, drop_first=True)
y = df['pass']

print("Feature matrix shape:", X.shape)
X.head()
# Out:
# Feature matrix shape: (649, 41)
#    age  Medu  Fedu  traveltime  studytime  failures  famrel  freetime  goout  \
# 0   18     4     4           2          2         0       4         3      4
# 1   17     1     1           1          2         0       5         3      3
# 2   15     1     1           1          2         0       4         3      2
# 3   15     4     2           1          3         0       3         2      2
# 4   16     3     3           1          2         0       4         3      2
#
#    Dalc  ...  guardian_mother  guardian_other  schoolsup_yes  famsup_yes  \
# 0     1  ...             True           False           True       False
# 1     1  ...            False           False          False        True
# 2     2  ...             True           False           True       False
# 3     1  ...             True           False          False        True
# 4     1  ...            False           False          False        True
#
#    paid_yes  activities_yes  nursery_yes  higher_yes  internet_yes  \
# 0     False           False         True        True         False
# 1     False           False        False        True          True
# 2     False           False         True        True          True
# 3     False            True         True        True          True
# 4     False           False         True        True         False
#
#    romantic_yes
# 0         False
# 1         False
# 2         False
# 3          True
# 4         False
#
# [5 rows x 41 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y,
    test_size=0.30,
    random_state=42,
    stratify=y
)

print("Training set shape:", X_train.shape)
print("Test set shape:", X_test.shape)
# Out:
# Training set shape: (454, 41)
# Test set shape: (195, 41)

# %%
logmodel = LogisticRegression(max_iter=5000)
logmodel.fit(X_train, y_train)
# Out:
# LogisticRegression(max_iter=5000)

# %%
predictions = logmodel.predict(X_test)

print("Accuracy:", round(accuracy_score(y_test, predictions), 4))
# Out:
# Accuracy: 0.9282

# %%
cm = confusion_matrix(y_test, predictions)
cm
# Out:
# array([[ 24,   6],
#        [  8, 157]])

# %%
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()

# %%
print(classification_report(y_test, predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.75      0.80      0.77        30
#            1       0.96      0.95      0.96       165
#
#     accuracy                           0.93       195
#    macro avg       0.86      0.88      0.87       195
# weighted avg       0.93      0.93      0.93       195

# %%
coef_df = pd.DataFrame({
    'Feature': X.columns,
    'Coefficient': logmodel.coef_[0]
})

coef_df['AbsCoefficient'] = coef_df['Coefficient'].abs()
coef_df = coef_df.sort_values('AbsCoefficient', ascending=False)

coef_df.head(15)
# Out:
#               Feature  Coefficient  AbsCoefficient
# 15          school_MS    -1.434812        1.434812
# 14                 G2     1.298511        1.298511
# 25         Fjob_other    -0.906782        0.906782
# 38         higher_yes     0.811503        0.811503
# 40       romantic_yes    -0.800319        0.800319
# 30  reason_reputation     0.781669        0.781669
# 13                 G1     0.734559        0.734559
# 26      Fjob_services    -0.722999        0.722999
# 20        Mjob_health     0.659634        0.659634
# 31    guardian_mother    -0.553966        0.553966
# 5            failures    -0.551741        0.551741
# 0                 age     0.477194        0.477194
# 39       internet_yes    -0.471817        0.471817
# 2                Fedu    -0.405863        0.405863
# 17          address_U     0.392109        0.392109

# %%
top_features = coef_df.head(15).sort_values('Coefficient')

plt.figure(figsize=(10, 8))
plt.barh(top_features['Feature'], top_features['Coefficient'])
plt.title('Top 15 Logistic Regression Coefficients')
plt.xlabel('Coefficient')
plt.show()
